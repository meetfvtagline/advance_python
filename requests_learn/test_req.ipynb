# %%
import requests
r = requests.get('https://api.github.com/events')
print(r.text)
# Out:
# [{"id":"6727878697","type":"PushEvent","actor":{"id":220040009,"login":"salamshegol","display_login":"salamshegol","gravatar_id":"","url":"https://api.github.com/users/salamshegol","avatar_url":"https://avatars.githubusercontent.com/u/220040009?"},"repo":{"id":1083143862,"name":"salamshegol/myproject_39513","url":"https://api.github.com/repos/salamshegol/myproject_39513"},"payload":{"repository_id":1083143862,"push_id":29021701852,"ref":"refs/heads/main","head":"9b4a8adbd384cb748b7e8e353e8ae32cccadadd1","before":"a31012481ff30625f7594701ea5aa6854953a3fe"},"public":true,"created_at":"2025-12-15T03:28:55Z"},{"id":"6727878576","type":"PushEvent","actor":{"id":104585684,"login":"aws-aemilia-fra","display_login":"aws-aemilia-fra","gravatar_id":"","url":"https://api.github.com/users/aws-aemilia-fra","avatar_url":"https://avatars.githubusercontent.com/u/104585684?"},"repo":{"id":1053834813,"name":"aws-aemilia-fra/Github-PR-Commit-Integration-Test-DoNotTouch-Gith-RB7P4TGB-v2-preprod-eu-centr
# ...

# %%
r.status_code
# Out:
# 200

# %%
r.headers['content-type']
# Out:
# 'application/json; charset=utf-8'

# %%
r.text
# Out:
# '[{"id":"6677727786","type":"PushEvent","actor":{"id":220040009,"login":"salamshegol","display_login":"salamshegol","gravatar_id":"","url":"https://api.github.com/users/salamshegol","avatar_url":"https://avatars.githubusercontent.com/u/220040009?"},"repo":{"id":1083143862,"name":"salamshegol/myproject_39513","url":"https://api.github.com/repos/salamshegol/myproject_39513"},"payload":{"repository_id":1083143862,"push_id":28971484512,"ref":"refs/heads/main","head":"e3ec669955665a78666453fc5381b38a3f91c4a5","before":"93d2f78c95492f75bf2f4af29b06793578f95df6"},"public":true,"created_at":"2025-12-12T11:58:24Z"},{"id":"6677727799","type":"PushEvent","actor":{"id":233810286,"login":"desarrolloprospectiva728-crypto","display_login":"desarrolloprospectiva728-crypto","gravatar_id":"","url":"https://api.github.com/users/desarrolloprospectiva728-crypto","avatar_url":"https://avatars.githubusercontent.com/u/233810286?"},"repo":{"id":1062007899,"name":"desarrolloprospectiva728-crypto/DATOSTH","url
# ...

# %%
r.json()
# Out:
# [{'id': '6677727786',
#   'type': 'PushEvent',
#   'actor': {'id': 220040009,
#    'login': 'salamshegol',
#    'display_login': 'salamshegol',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/salamshegol',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/220040009?'},
#   'repo': {'id': 1083143862,
#    'name': 'salamshegol/myproject_39513',
#    'url': 'https://api.github.com/repos/salamshegol/myproject_39513'},
#   'payload': {'repository_id': 1083143862,
#    'push_id': 28971484512,
#    'ref': 'refs/heads/main',
#    'head': 'e3ec669955665a78666453fc5381b38a3f91c4a5',
#    'before': '93d2f78c95492f75bf2f4af29b06793578f95df6'},
#   'public': True,
#   'created_at': '2025-12-12T11:58:24Z'},
#  {'id': '6677727799',
#   'type': 'PushEvent',
#   'actor': {'id': 233810286,
#    'login': 'desarrolloprospectiva728-crypto',
#    'display_login': 'desarrolloprospectiva728-crypto',
#    'gravatar_id': '',
# ...

# %%
payload = {'name': 'meet', 'age': 32}
r = requests.get('https://httpbin.org/get', params=payload)
print(r.url)
# Out:
# https://httpbin.org/get?name=meet&age=32

# %%
payload = {'name': 'meet', 'age': 32,'skils':['python','ml','dl']}
r = requests.get('https://httpbin.org/get', params=payload)
print(r.url)
# Out:
# https://httpbin.org/get?name=meet&age=32&skils=python&skils=ml&skils=dl

# %%
r=requests.get('https://api.github.com/events')
print(r.text)
# Out:
# [{"id":"6728039415","type":"CreateEvent","actor":{"id":15697789,"login":"evanwyatt","display_login":"evanwyatt","gravatar_id":"","url":"https://api.github.com/users/evanwyatt","avatar_url":"https://avatars.githubusercontent.com/u/15697789?"},"repo":{"id":1116553814,"name":"evanwyatt/PlaceFootprints","url":"https://api.github.com/repos/evanwyatt/PlaceFootprints"},"payload":{"ref":"column-major","ref_type":"branch","full_ref":"refs/heads/column-major","master_branch":"main","description":null,"pusher_type":"user"},"public":true,"created_at":"2025-12-15T03:41:43Z"},{"id":"6728039384","type":"PushEvent","actor":{"id":41898282,"login":"github-actions[bot]","display_login":"github-actions","gravatar_id":"","url":"https://api.github.com/users/github-actions[bot]","avatar_url":"https://avatars.githubusercontent.com/u/41898282?"},"repo":{"id":632479239,"name":"Future-StarFire/autoGreen","url":"https://api.github.com/repos/Future-StarFire/autoGreen"},"payload":{"repository_id":632479239,"push_
# ...

# %%
r.encoding
# Out:
# 'utf-8'

# %%
r.content
# Out:
# b'[{"id":"6728039415","type":"CreateEvent","actor":{"id":15697789,"login":"evanwyatt","display_login":"evanwyatt","gravatar_id":"","url":"https://api.github.com/users/evanwyatt","avatar_url":"https://avatars.githubusercontent.com/u/15697789?"},"repo":{"id":1116553814,"name":"evanwyatt/PlaceFootprints","url":"https://api.github.com/repos/evanwyatt/PlaceFootprints"},"payload":{"ref":"column-major","ref_type":"branch","full_ref":"refs/heads/column-major","master_branch":"main","description":null,"pusher_type":"user"},"public":true,"created_at":"2025-12-15T03:41:43Z"},{"id":"6728039384","type":"PushEvent","actor":{"id":41898282,"login":"github-actions[bot]","display_login":"github-actions","gravatar_id":"","url":"https://api.github.com/users/github-actions[bot]","avatar_url":"https://avatars.githubusercontent.com/u/41898282?"},"repo":{"id":632479239,"name":"Future-StarFire/autoGreen","url":"https://api.github.com/repos/Future-StarFire/autoGreen"},"payload":{"repository_id":632479239,"pus
# ...

# %%
from PIL import Image
from io import BytesIO

# %%
i=Image.open(BytesIO(r.content))
# Out:
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 i=Image.open(BytesIO(r.content))
#
# File ~/Documents/advance_topic/.venv/lib/python3.10/site-packages/PIL/Image.py:3560, in open(fp, mode, formats)
#    3558     warnings.warn(message)
#    3559 msg = "cannot identify image file %r" % (filename if filename else fp)
# -> 3560 raise UnidentifiedImageError(msg)
#
# UnidentifiedImageError: cannot identify image file <_io.BytesIO object at 0x10ad96660>

# %%
r.json()
# Out:
# [{'id': '6728039415',
#   'type': 'CreateEvent',
#   'actor': {'id': 15697789,
#    'login': 'evanwyatt',
#    'display_login': 'evanwyatt',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/evanwyatt',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/15697789?'},
#   'repo': {'id': 1116553814,
#    'name': 'evanwyatt/PlaceFootprints',
#    'url': 'https://api.github.com/repos/evanwyatt/PlaceFootprints'},
#   'payload': {'ref': 'column-major',
#    'ref_type': 'branch',
#    'full_ref': 'refs/heads/column-major',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2025-12-15T03:41:43Z'},
#  {'id': '6728039384',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
# ...

# %%
r.raw

# %%
r.raw.read(10)
# Out:
# b''

# %%
with open('github_events.json', 'wb') as f:
    for chunk in r.iter_content(chunk_size=128):
        f.write(chunk)

# %%
url='https://api.github.com/some/endpoint'
headers = {'user-agent': 'my-app/0.0.1'}
r=requests.get(url,headers=headers)

# %%
r.json()
# Out:
# {'message': 'Not Found',
#  'documentation_url': 'https://docs.github.com/rest',
#  'status': '404'}

# %%
payload={'key1': 'value1', 'key2': 'value2'}

r=requests.post('https://httpbin.org/post', data=payload)
r.text
# Out:
# '{\n  "args": {}, \n  "data": "", \n  "files": {}, \n  "form": {\n    "key1": "value1", \n    "key2": "value2"\n  }, \n  "headers": {\n    "Accept": "*/*", \n    "Accept-Encoding": "gzip, deflate", \n    "Content-Length": "23", \n    "Content-Type": "application/x-www-form-urlencoded", \n    "Host": "httpbin.org", \n    "User-Agent": "python-requests/2.32.5", \n    "X-Amzn-Trace-Id": "Root=1-693f8b6d-265668e01b16e7112e6786bd"\n  }, \n  "json": null, \n  "origin": "43.251.72.102", \n  "url": "https://httpbin.org/post"\n}\n'

# %%
tuple_payload=[('key1','value1'),('key2','value2')]
r=requests.post('https://httpbin.org/post', data=tuple_payload)
r.text
r.url
# Out:
# 'https://httpbin.org/post'

# %%
dict_payload={'key1':'value1','key2':'value2'}
r1=requests.post('https://httpbin.org/post', data=dict_payload)
r1.text
# Out:
# '{\n  "args": {}, \n  "data": "", \n  "files": {}, \n  "form": {\n    "key1": "value1", \n    "key2": "value2"\n  }, \n  "headers": {\n    "Accept": "*/*", \n    "Accept-Encoding": "gzip, deflate", \n    "Content-Length": "23", \n    "Content-Type": "application/x-www-form-urlencoded", \n    "Host": "httpbin.org", \n    "User-Agent": "python-requests/2.32.5", \n    "X-Amzn-Trace-Id": "Root=1-693f8c7b-5f7b8f3a1003ad8367843989"\n  }, \n  "json": null, \n  "origin": "43.251.72.102", \n  "url": "https://httpbin.org/post"\n}\n'

# %%
r.text==r1.text
# Out:
# False

# %%
import json

url = 'https://api.github.com/some/endpoint'
payload = {'some': 'data'}

r = requests.post(url, data=json.dumps(payload))

# %%
r.url
# Out:
# 'https://api.github.com/some/endpoint'

# %%
url = 'http://example.com/some/cookie/setting/url'
r=requests.get(url)
r.cookies['working']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[48], line 3
#       1 url = 'http://example.com/some/cookie/setting/url'
#       2 r=requests.get(url)
# ----> 3 r.cookies['working']
#
# File ~/Documents/advance_topic/.venv/lib/python3.10/site-packages/requests/cookies.py:334, in RequestsCookieJar.__getitem__(self, name)
#     327 def __getitem__(self, name):
#     328     """Dict-like __getitem__() for compatibility with client code. Throws
#     329     exception if there are more than one cookie with name. In that case,
#     330     use the more explicit get() method instead.
#     331
#     332     .. warning:: operation is O(n), not O(1).
#     333     """
# --> 334     return self._find_no_duplicates(name)
#
# ...

# %%
import requests
url = 'https://httpbin.org/cookies'
cookies=dict(cookies_are='working')

r=requests.get(url, cookies=cookies)
r.text
# Out:
# '{\n  "cookies": {\n    "cookies_are": "working"\n  }\n}\n'

# %%
r.url
# Out:
# 'https://httpbin.org/cookies'

# %%
jar=requests.cookies.RequestsCookieJar()
jar.set('tasty_cookie','yum',domain='httpbin.org',path='/cookies')
jar.set('gross_Cookie','blech',domain='httpbin.org',path='/elsewhere')
url='https://httpbin.org/elsewhere'
r=requests.get(url,cookies=jar)

# %%
r.text
# Out:
# '<html>\r\n<head><title>503 Service Temporarily Unavailable</title></head>\r\n<body>\r\n<center><h1>503 Service Temporarily Unavailable</h1></center>\r\n</body>\r\n</html>\r\n'

# %%
s = requests.Session()

s.get('https://httpbin.org/cookies/set/sessioncookie/123456789')
r = s.get('https://httpbin.org/cookies')

print(r.text)
{"cookies": {"sessioncookie": "123456789"}}
# Out:
# <html>
# <head><title>503 Service Temporarily Unavailable</title></head>
# <body>
# <center><h1>503 Service Temporarily Unavailable</h1></center>
# </body>
# </html>
# {'cookies': {'sessioncookie': '123456789'}}
